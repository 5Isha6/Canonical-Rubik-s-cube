# %%
import numpy as np
from functools import lru_cache

# %%
forms_fp = "./rubiks-example.txt"

# %%
forms = open(forms_fp, 'r').read()
forms_dict = {}
for i,form in enumerate(forms.split(':')[1:]):
  forms_dict[i] = form.split('Form')[0]

# %% [markdown]
# # New Section

# %%
class RubiksHandler():

  def __init__(self,
               tensor = None,
               text = None,
               canonical_form: dict = {'top':    'Y',
                                       'left':   'G',
                                       'front':  'W',
                                       'right':  'O',
                                       'back':   'B',
                                       'bottom': 'R'
                                      },
              ):
    self.canonical_form = canonical_form
    if tensor==None and text==None:
      raise "Must provide atleast one, tensor or txt"

    if  not tensor:
      self.text = text
      self.tensor = self._text2tensor()
    else:
      self.tensor = tensor
      self.text = self._tensor2text()

    self.top,self.front,self.left,self.right,self.back,self.bottom = self.tensor

  def update(self):
    self.tensor = np.array([self.top,self.front,self.left,self.right,self.back,self.bottom])
    self.text = self._tensor2text()

  def toCanonical(self):
    currForm = self.currForm()    
    relationMap = {
        currForm['top']:self.canonical_form['top'],
        currForm['left']:self.canonical_form['left'],
        currForm['front']:self.canonical_form['front'],
        currForm['right']:self.canonical_form['right'],
        currForm['back']:self.canonical_form['back'],
        currForm['bottom']:self.canonical_form['bottom']
        }
    self.translate(relationMap)

  def _text2tensor(self):
    txt = self.text
    top = [[],[],[]]
    top_c = txt[9:44].split()
    top[0] = top_c[:3]
    top[1] = top_c[3:6]
    top[2] = top_c[6:9]

    front = [[],[],[]]
    front[0] = txt[54:59].split()
    front[1] = txt[81:86].split()
    front[2] = txt[108:113].split()

    left = [[],[],[]]
    left[0] = txt[48:53].split()
    left[1] = txt[75:80].split()
    left[2] = txt[102:107].split()

    right = [[],[],[]]
    right[0] = txt[60:65].split()
    right[1] = txt[87:92].split()
    right[2] = txt[114:119].split()

    back = [[],[],[]]
    back[0] = txt[66:71].split()
    back[1] = txt[93:98].split()
    back[2] = txt[120:125].split()

    bottom = [[],[],[]]
    bottom_c = txt[135:170].split()
    bottom[0] = bottom_c[:3]
    bottom[1] = bottom_c[3:6]
    bottom[2] = bottom_c[6:9]

    return np.array([top,front,left,right,back,bottom])
  
  def _tensor2text(self):

    empty = [' ',' ',' ']
    top, front, left, right, back, bottom = self.tensor
    
    text  =  ' '.join(empty)   + ' ' + ' '.join(top[0])    + ' ' + ' '.join(empty)    + ' ' + ' '.join(empty)   + '\n'
    text +=  ' '.join(empty)   + ' ' + ' '.join(top[1])    + ' ' + ' '.join(empty)    + ' ' + ' '.join(empty)   + '\n'
    text +=  ' '.join(empty)   + ' ' + ' '.join(top[2])    + ' ' + ' '.join(empty)    + ' ' + ' '.join(empty)   + '\n'
    text +=  ' '.join(left[0]) + ' ' + ' '.join(front[0])  + ' ' + ' '.join(right[0]) + ' ' + ' '.join(back[0]) + '\n'
    text +=  ' '.join(left[1]) + ' ' + ' '.join(front[1])  + ' ' + ' '.join(right[1]) + ' ' + ' '.join(back[1]) + '\n'
    text +=  ' '.join(left[2]) + ' ' + ' '.join(front[2])  + ' ' + ' '.join(right[2]) + ' ' + ' '.join(back[2]) + '\n'
    text +=  ' '.join(empty)   + ' ' + ' '.join(bottom[0]) + ' ' + ' '.join(empty)    + ' ' + ' '.join(empty)   + '\n'
    text +=  ' '.join(empty)   + ' ' + ' '.join(bottom[1]) + ' ' + ' '.join(empty)    + ' ' + ' '.join(empty)   + '\n'
    text +=  ' '.join(empty)   + ' ' + ' '.join(bottom[2]) + ' ' + ' '.join(empty)    + ' ' + ' '.join(empty)   + '\n'

    return text
  
  def translate(self, relationMap):
    self.text = self.text.translate(str.maketrans(relationMap))
    self.tensor = self._text2tensor()

  def _findFaceColor(self, face):
    return face[1,1]

  def currForm(self):
    top, front, left, right, back, bottom = self.tensor
    d = {
        'top':    self._findFaceColor(top),
        'front':  self._findFaceColor(front),
        'left':   self._findFaceColor(left),
        'right':  self._findFaceColor(right),
        'back':   self._findFaceColor(back),
        'bottom': self._findFaceColor(bottom)
        }

    return d

# %%
print(forms_dict[0])
# Out:
#         Y Y R
#         G Y O
#         O R Y
#   W W W R W W O R W G B G
#   O G G B W R B O Y O B B
#   R G R O R B Y O B O W G
#         B G G
#         Y R W
#         B Y Y

# %%
out_str = ""
for i in range(1,len(forms_dict)):
   rh = RubiksHandler(text = forms_dict[i])
   rh.toCanonical()
   out_str += f"\nForm {i}:\n"
   out_str += "Original Form:\n"
   out_str += forms_dict[i]
   out_str += "\nCanonical Form:\n"
   out_str += rh.text
output = open("rubiks-output.txt","w")
output.write(out_str)
output.close()
print(out_str[:10000])
# Out:
# Form 1:
# Original Form:
#
#         R G G
#         B O W
#         R B B
#   O G O G W Y R Y B R O Y
#   G G Y R R Y B Y R O W R
#   W W W G R G W O Y W W O
#         B B O
#         G B Y
#         Y O B
#
# Canonical Form:
#
#         W G G
#         R Y B
#         W R R
#   Y G Y G B O W O R W Y O
#   G G O W W O R O W Y B W
#   B B B G W G B Y O B B Y
#         R R Y
#         G R O
#         O Y R
#
# Form 2:
# Original Form:
#
#         Y R B
#         G W W
#         W B R
#   G W R Y G B O Y R W W O
#   R R G Y Y G O G R Y B B
#   R O W G B W B R B O B O
#         Y O G
#         Y O O
#         Y W G
#
# Canonical Form:
#
#         W G B
#         O Y Y
#         Y B G
#   O Y G W O B R W G Y Y R
#   G G O W W O R O G W B B
#   G R Y O B Y B G B R B R
#         W R O
#         W R R
#         W Y O
#
# Form 3:
# Original Form:
#
#         W Y Y
#         O G B
#         W O O
#   G Y G Y B R W R O W G R
#   Y Y R W W R O R W G B W
#   B B B Y W Y B G R B B G
#         O O G
#         Y O R
#         R G O
#
# Canonical Form:
#
#         W G G
#         R Y B
#         W R R
#   Y G Y G B O W O R W Y O
#   G G O W W O R O W Y B W
#   B B B G W G B Y O B B Y
#         R R Y
#         G R O
#         O Y R
#
# Form 4:
# Original Form:
#
#         W B G
#         B R W
#         R R B
#   Y W G Y B G R O B W O O
#   G G B G Y O R O O Y B R
#   W Y R B Y Y R G B W Y Y
#         O W O
#         G W W
#         G R O
#
# Canonical Form:
#
#         R B G
#         B Y R
#         Y Y B
#   W R G W B G Y O B R O O
#   G G B G W O Y O O W B Y
#   R W Y B W W Y G B R W W
#         O R O
#         G R R
#         G Y O
#
# Form 5:
# Original Form:
#
#         W W O
#         G Y Y
#         O Y O
#   R R Y B W G R R B G R Y
#   G B R O O G O R W B W W
#   O O Y B O G W B R W Y R
#         W Y B
#         B G G
#         Y B G
#
# Canonical Form:
#
#         B B W
#         R Y Y
#         W Y W
#   O O Y G B R O O G R O Y
#   R G O W W R W O B G B B
#   W W Y G W R B G O B Y O
#         B Y G
#         G R R
#         Y G R
#
# Form 6:
# Original Form:
#
#         B O G
#         Y G G
#         G B Y
#   Y W W B Y W O R O W W W
#   R W Y R B G B R R B O O
#   B Y R G B R B W O Y O Y
#         O W G
#         O Y G
#         R G R
#
# Canonical Form:
#
#         W B Y
#         R Y Y
#         Y W R
#   R G G W R G B O B G G G
#   O G R O W Y W O O W B B
#   W R O Y W O W G B R B R
#         B G Y
#         B R Y
#         O Y O
#
# Form 7:
# Original Form:
#
#         W B W
#         B B O
#         W G G
#   R R Y O R B R R B Y G O
#   W R G Y G G O Y R W W O
#   G Y R G B R W W B Y W O
#         O Y B
#         O O Y
#         Y B G
#
# Canonical Form:
#
#         B Y B
#         Y Y R
#         B W W
#   G G O R G Y G G Y O W R
#   B G W O W W R O G B B R
#   W O G W Y G B B Y O B R
#         R O Y
#         R R O
#         O Y W
#
# Form 8:
# Original Form:
#
#         Y W R
#         O Y B
#         B Y O
#   R W O G R B Y Y G W Y B
#   R R W G W B R O O B B W
#   W O Y O B O G O G B G Y
#         W G W
#         G G Y
#         R R R
#
# Canonical Form:
#
#         Y W G
#         O Y B
#         B Y O
#   G W O R G B Y Y R W Y B
#   G G W R W B G O O B B W
#   W O Y O B O R O R B R Y
#         W R W
#         R R Y
#         G G G
#
# Form 9:
# Original Form:
#
#         O W W
#         Y W O
#         B O Y
#   W G O Y G G R Y B R O B
#   W G G R O W B B O B R G
#   W B O Y R R Y R W O R R
#         G W B
#         Y Y B
#         G Y G
#
# Canonical Form:
#
#         W Y Y
#         R Y W
#         O W R
#   Y G W R G G B R O B W O
#   Y G G B W Y O O W O B G
#   Y O W R B B R B Y W B B
#         G Y O
#         R R O
#         G R G
#
# Form 10:
# Original Form:
#
#         B B G
#         Y R B
#         O O G
#   G W B G R W R O R O Y W
#   B W G R Y G O O W G G W
#   Y R W Y Y R Y Y Y O G O
#         B R W
#         W B O
#         R B B
#
# Canonical Form:
#
#         R R B
#         W Y R
#         O O B
#   B G R B Y G Y O Y O W G
#   R G B Y W B O O G B B G
#   W Y G W W Y W W W O B O
#         R Y G
#         G R O
#         Y R R
#
# Form 11:
# Original Form:
#
#         O Y G
#         G G O
#         G R Y
#   R B R W W W O W W Y O W
#   Y B B Y R R B W O B Y G
#   Y W R O R O Y O B G Y B
#         B G B
#         G O R
#         G W R
#
# Canonical Form:
#
#         R B Y
#         Y Y R
#         Y W B
#   W G W O O O R O O B R O
#   B G G B W W G O R G B Y
#   B O W R W R B R G Y B G
#         G Y G
#         Y R W
#         Y O W
#
# Form 12:
# Original Form:
#
#         Y B G
#         G O O
#         B G O
#   B R R W B Y W G Y O R G
#   W G O Y Y G Y W R O R R
#   B W W B W O G W W O Y G
#         Y Y R
#         O B B
#         R B R
#
# Canonical Form:
#
#         W R G
#         G Y Y
#         R G Y
#   R B B O R W O G W Y B G
#   O G Y W W G W O B Y B B
#   R O O R O Y G O O Y W G
#         W W B
#         Y R R
#         B R B
#
# Form 13:
# Original Form:
#
#         B W Y
#         R R Y
#         B R Y
#   O G O W O B W R G R O R
#   G B R B Y Y B G G O O Y
#   G Y R O B Y G W B R W W
#         G O W
#         W W B
#         O G Y
#
# Canonical Form:
#
#         G R W
#         Y Y W
#         G Y W
#   B O B R B G R Y O Y B Y
#   O G Y G W W G O O B B W
#   O W Y B G W O R G Y R R
#         O B R
#         R R G
#         B O W
#
# Form 14:
# Original Form:
#
#         W G W
#         G G Y
#         W R R
#   O O B Y O G O O G B R Y
#   W O R B R R Y B O W W Y
#   R B O R G O W W G B W Y
#         Y B G
#         Y Y B
#         B G R
#
# Canonical Form:
#
#         B Y B
#         Y Y R
#         B W W
#   G G O R G Y G G Y O W R
#   B G W O W W R O G B B R
#   W O G W Y G B B Y O B R
#         R O Y
#         R R O
#         O Y W
#
# Form 15:
# Original Form:
#
#         O R W
#         W Y Y
#         R W Y
#   R B B G R O G W O Y B W
#   G W Y O O W O G B Y B B
#   R G G R G Y W G G Y O W
#         O O B
#         Y R R
#         B R B
#
# Canonical Form:
#
#         W R G
#         G Y Y
#         R G Y
#   R B B O R W O G W Y B G
#   O G Y W W G W O B Y B B
#   R O O R O Y G O O Y W G
#         W W B
#         Y R R
#         B R B
#
# Form 16:
# Original Form:
#
#         R W G
#         G W R
#         Y B W
#   W W O B W G Y B R O Y G
#   Y R R G G B Y Y B O B G
#   O R O G O W B R W R G R
#         Y Y Y
#         W O O
#         B O B
#
# Canonical Form:
#
#         G Y W
#         W Y G
#         O B Y
#   Y Y R B Y W O B G R O W
#   O G G W W B O O B R B W
#   R G R W R Y B G Y G W G
#         O O O
#         Y R R
#         B R B
#
# Form 17:
# Original Form:
#
#         R G R
#         O G G
#         O B R
#   B W G W W G Y O B W W Y
#   Y O O B Y W R R B R W O
#   O G W R R G Y R B O Y W
#         G Y O
#         Y B G
#         B B Y
#
# Canonical Form:
#
#         O Y O
#         G Y Y
#         G R O
#   R B Y B B Y W G R B B W
#   W G G R W B O O R O B G
#   G Y B O O Y W O R G W B
#         Y W G
#         W R Y
#         R R W
#
# Form 18:
# Original Form:
#
#         O B G
#         Y G G
#         G O Y
#   Y W W O Y W B R B W W W
#   R W Y R O G O R R O B B
#   O Y R G O R O W B Y B Y
#         B W G
#         B Y G
#         R G R
#
# Canonical Form:
#
#         W B Y
#         R Y Y
#         Y W R
#   R G G W R G B O B G G G
#   O G R O W Y W O O W B B
#   W R O Y W O W G B R B R
#         B G Y
#         B R Y
#         O Y O
#
# Form 19:
# Original Form:
#
#         G Y W
#         W W G
#         W R Y
#   R B R O O O G O O Y G O
#   Y B B Y R R B O G B Y W
#   Y O R G R G Y G B W Y B
#         B W B
#         W G R
#         W O R
#
# Canonical Form:
#
#         R B Y
#         Y Y R
#         Y W B
#   W G W O O O R O O B R O
#   B G G B W W G O R G B Y
#   B O W R W R B R G Y B G
#         G Y G
#         Y R W
#         Y O W
#
# Form 20:
# Original Form:
#
#         G G Y
#         O W G
#         B B Y
#   Y R G Y W R W B W B O R
#   G R Y W O Y B B R Y Y R
#   O W R O O W O O O B Y B
#         G W R
#         R G B
#         W G G
#
# Canonical Form:
#
#         R R B
#         W Y R
#         O O B
#   B G R B Y G Y O Y O W G
#   R G B Y W B O O G B B G
#   W Y G W W Y W W W O B O
#         R Y G
#         G R O
#         Y R R
#
# Form 21:
# Original Form:
#
#         O Y R
#         O O Y
#         Y R W
#   B Y W O G Y R G G B R W
#   W B G O G G B Y O W W Y
#   Y B B O W Y R B B R B O
#         G R G
#         R R O
#         G W W
#
# Canonical Form:
#
#         Y O R
#         Y Y O
#         O R B
#   G O B Y W O R W W G R B
#   B G W Y W W G O Y B B O
#   O G G Y B O R G G R G Y
#         W R W
#         R R Y
#         W B B
#
# Form 22:
# Original Form:
#
#         O W O
#         W W B
#         G G G
#   B R O B W Y W R W R Y R
#   O G G O Y Y R R G Y O W
#   R O G Y B O W B B Y G W
#         B O G
#         R B Y
#         Y B R
#
# Canonical Form:
#
#         B Y B
#         Y Y R
#         G G G
#   R O B R Y W Y O Y O W O
#   B G G B W W O O G W B Y
#   O B G W R B Y R R W G Y
#         R B G
#         O R W
#         W R O
#
# Form 23:
# Original Form:
#
#         R O O
#         B O R
#         G R B
#   O Y R B Y Y W B G W R G
#   O Y Y W R O G G R G W Y
#   O G R B W W B W O R W W
#         Y O G
#         B B G
#         Y B Y
#
# Canonical Form:
#
#         W Y Y
#         R Y W
#         O W R
#   Y G W R G G B R O B W O
#   Y G G B W Y O O W O B G
#   Y O W R B B R B Y W B B
#         G Y O
#         R R O
#         G R G
#
# Form 24:
# Original Form:
#
#         R O G
#         B B G
#         R B R
#   Y G O W W Y O W B W W B
#   R R O R W G Y G G O Y W
#   Y R O G Y W G B W R R B
#         Y O O
#         B O Y
#         G Y B
#
# Canonical Form:
#
#         G R O
#         Y Y O
#         G Y G
#   B O R W W B R W Y W W Y
#   G G R G W O B O O R B W
#   B G R O B W O Y W G G Y
#         B R R
#         Y R B
#         O B Y
#
# Form 25:
# Original Form:
#
#         G O W
#         B B W
#         G B W
#   R Y R O R G O B Y B R B
#   Y G B G W W G Y Y R R W
#   Y W B R G W Y O G B O O
#         Y R O
#         O O G
#         R Y W
#
# Canonical Form:
#
#         G R W
#         Y Y W
#         G Y W
#   B O B R B G R Y O Y B Y
#   O G Y G W W G O O B B W
#   O W Y B G W O R G Y R R
#         O B R
#         R R G
#         B O W
#
# Form 26:
# Original Form:
#
#         O Y R
#         R R O
#         R W Y
#   W G W B B B O B B Y O B
#   Y G G Y W W G B O G Y R
#   Y B W O W O Y O G R Y G
#         G R G
#         R O W
#         R B W
#
# Canonical Form:
#
#         R B Y
#         Y Y R
#         Y W B
#   W G W O O O R O O B R O
#   B G G B W W G O R G B Y
#   B O W R W R B R G Y B G
#         G Y G
